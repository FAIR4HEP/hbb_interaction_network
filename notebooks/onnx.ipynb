# %%
# !pip install onnx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: onnx in /home/ruike/.local/lib/python3.8/site-packages (1.12.0)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages (from onnx) (3.19.4)
# Requirement already satisfied: numpy>=1.16.6 in /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages (from onnx) (1.23.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /home/ruike/.local/lib/python3.8/site-packages (from onnx) (4.3.0)

# %%
import numpy as np
import torch
# import setGPU
import argparse
import onnx
import onnxruntime as ort
import warnings
import os
import sys
import time
import glob
import sklearn.metrics as _m


import sys 
sys.path.append("..") 
from src.models.models import GraphNet

# %%
sv_branch = 1
N = 60 # number of charged particles
N_sv = 5 # number of SVs 
n_targets = 2 # number of classes
save_path = '//grand/RAPINS/ruike/new_hbb/test/'
print( ort.get_device()  )

params_2 = ['track_ptrel',     
          'track_erel',     
          'track_phirel',     
          'track_etarel',     
          'track_deltaR',
          'track_drminsv',     
          'track_drsubjet1',     
          'track_drsubjet2',
          'track_dz',     
          'track_dzsig',     
          'track_dxy',     
          'track_dxysig',     
          'track_normchi2',     
          'track_quality',     
          'track_dptdpt',     
          'track_detadeta',     
          'track_dphidphi',     
          'track_dxydxy',     
          'track_dzdz',     
          'track_dxydz',     
          'track_dphidxy',     
          'track_dlambdadz',     
          'trackBTag_EtaRel',     
          'trackBTag_PtRatio',     
          'trackBTag_PParRatio',     
          'trackBTag_Sip2dVal',     
          'trackBTag_Sip2dSig',     
          'trackBTag_Sip3dVal',     
          'trackBTag_Sip3dSig',     
          'trackBTag_JetDistVal'
         ]

params_3 = ['sv_ptrel',
          'sv_erel',
          'sv_phirel',
          'sv_etarel',
          'sv_deltaR',
          'sv_pt',
          'sv_mass',
          'sv_ntracks',
          'sv_normchi2',
          'sv_dxy',
          'sv_dxysig',
          'sv_d3d',
          'sv_d3dsig',
          'sv_costhetasvpv'
         ]
# Out:
# CPU

# %%
test_2_arrays = []
test_3_arrays = []
target_test_arrays = []
test_spec_arrays = []
    
for test_file in sorted(glob.glob(save_path + 'test_*_features_2.npy')):
    print(test_file)
    test_2_arrays.append(np.load(test_file))  
print(np.shape(test_2_arrays))
test_2 = np.concatenate(test_2_arrays)

for test_file in sorted(glob.glob(save_path + 'test_*_features_3.npy')):
    test_3_arrays.append(np.load(test_file))
test_3 = np.concatenate(test_3_arrays)

for test_file in sorted(glob.glob(save_path + 'test_*_spectators_0.npy')):
    test_spec_arrays.append(np.load(test_file))
test_spec = np.concatenate(test_spec_arrays)

for test_file in sorted(glob.glob(save_path + 'test_*_truth_0.npy')):
    target_test_arrays.append(np.load(test_file))
label_all = np.concatenate(target_test_arrays)
        
        
print(len(label_all))        
        

test_2 = np.swapaxes(test_2, 1, 2)
test_3 = np.swapaxes(test_3, 1, 2)
test_spec = np.swapaxes(test_spec, 1, 2)
fj_pt = test_spec[:,0,0]
fj_eta = test_spec[:,1,0]
fj_sdmass = test_spec[:,2,0]

print("before",test_2.shape)
print("before",test_3.shape)


no_undef = fj_pt > -999 # no cut

min_pt = -999 #300
max_pt = 99999 #2000
min_eta = -999 # no cut
max_eta = 999 # no cut
min_msd = -999 #40
max_msd = 9999 #200


test_2 = test_2[(fj_sdmass > min_msd) & (fj_sdmass < max_msd) & (fj_eta > min_eta) & (fj_eta < max_eta) & (fj_pt > min_pt) & (fj_pt < max_pt) & no_undef]
test_3 = test_3[(fj_sdmass > min_msd) & (fj_sdmass < max_msd) & (fj_eta > min_eta) & (fj_eta < max_eta) & (fj_pt > min_pt) & (fj_pt < max_pt) & no_undef]
test_spec = test_spec[(fj_sdmass > min_msd) & (fj_sdmass < max_msd) & (fj_eta > min_eta) & (fj_eta < max_eta) & (fj_pt > min_pt) & (fj_pt < max_pt) & no_undef ]
label_all = label_all[(fj_sdmass > min_msd) & (fj_sdmass < max_msd) & (fj_eta > min_eta) & (fj_eta < max_eta) & (fj_pt > min_pt) & (fj_pt < max_pt) & no_undef ]


print("after",test_2.shape)
print("after",test_3.shape)


test = test_2
params = params_2
test_sv = test_3
params_sv = params_3

label = 'new'
gnn = GraphNet(N, n_targets, len(params), 60, N_sv, len(params_sv),
               vv_branch=0, #int(args.vv_branch),
               De=20,#args.De,
               Do=24 ,#args.Do,
               softmax=True)


gnn.load_state_dict(torch.load('../models/trained_models/random_gnn_%s_last.pth'%(label), map_location=torch.device('cuda')))
torch.save(gnn.state_dict(),'../models/trained_models/random_gnn_%s_last.pth'%(label))


torch_soft_res = []
onnx_soft_res=[]
torch_res= []
onnx_res=[]
pytorch_time=[]
onnx_time=[]
label_ =[]

sample_size = 1800000 
batch_size= 128 
model_path = "../models/trained_models/onnx_model/5_10_gnn_%s.onnx"%batch_size


#build onnx model
label_batch = label_all[1:1+batch_size]

dummy_input_1 = torch.from_numpy(test[1:1+batch_size]).cuda()
dummy_input_2 = torch.from_numpy(test_sv[1:1+batch_size]).cuda() 

input_names = ['input_cpf', 'input_sv']
output_names = ['output1']
torch.onnx.export(gnn, (dummy_input_1, dummy_input_2), model_path, verbose=True,
                input_names = input_names, output_names = output_names,
                export_params=True,    # store the trained parameter weights inside the model file
                opset_version=11,      # the ONNX version to export the model to
                dynamic_axes = {input_names[0]: {0: 'batch_size'}, 
                            input_names[1]: {0: 'batch_size'}, 
                            output_names[0]: {0: 'batch_size'}})
# Out:
# //grand/RAPINS/ruike/new_hbb/test/test_0_features_2.npy
# //grand/RAPINS/ruike/new_hbb/test/test_1_features_2.npy
# //grand/RAPINS/ruike/new_hbb/test/test_2_features_2.npy
# (3, 600000, 60, 30)
# 1800000
# before (1800000, 30, 60)
# before (1800000, 14, 5)
# after (1800000, 30, 60)
# after (1800000, 14, 5)
# Exported graph: graph(%input_cpf : Float(*, 30, 60, strides=[1800, 1, 30], requires_grad=0, device=cuda:0),
#       %input_sv : Float(*, 14, 5, strides=[70, 1, 14], requires_grad=0, device=cuda:0),
#       %fr1.weight : Float(60, 60, strides=[60, 1], requires_grad=1, device=cuda:0),
#       %fr1.bias : Float(60, strides=[1], requires_grad=1, device=cuda:0),
#       %fr2.weight : Float(60, 60, strides=[60, 1], requires_grad=1, device=cuda:0),
#       %fr2.bias : Float(60, strides=[1], requires_grad=1, device=cuda:0),
#       %fr3.weight : Float(20, 60, strides=[60, 1], requires_grad=1, device=cuda:0),
#       %fr3.bias : Float(20, strides=[1], requires_grad=1, device=cuda:0),
#       %fr1_pv.weight : Float(60, 44, strides=[44, 1], requires_grad=1, device=cuda:0),
#       %fr1_pv.bias : Float(60, strides=[1], requires_grad=1, device=cuda:0),
#       %fr2_pv.weight : Float(60, 60, strides=[60, 1], requires_grad=1, device=cuda:0),
#       %fr2_pv.bias : Float(60, strides=[1], requires_grad=1, device=cuda:0),
#       %fr3_pv.weight : Float(20, 60, strides=[60, 1], requires_grad=1, device=cuda:0),
#       %fr3_pv.bias : Float(20, strides=[1], requires_grad=1, device=cuda:0),
#       %fo1.weight : Float(60, 70, strides=[70, 1], requires_grad=1, device=cuda:0),
#       %fo1.bias : Float(60, strides=[1], requires_grad=1, device=cuda:0),
#       %fo2.weight : Float(60, 60, strides=[60, 1], requires_grad=1, device=cuda:0),
#       %fo2.bias : Float(60, strides=[1], requires_grad=1, device=cuda:0),
#       %fo3.weight : Float(24, 60, strides=[60, 1], requires_grad=1, device=cuda:0),
#       %fo3.bias : Float(24, strides=[1], requires_grad=1, device=cuda:0),
#       %fc_fixed.weight : Float(2, 24, strides=[24, 1], requires_grad=1, device=cuda:0),
#       %fc_fixed.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %onnx::Concat_183 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Concat_185 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Concat_191 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Concat_194 : Long(1, strides=[1], requires_grad=0, device=cpu)):
#   %onnx::Concat_200 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_0"](%onnx::Concat_191)
#   %onnx::Concat_199 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_1"](%onnx::Concat_183)
#   %onnx::Concat_198 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_2"](%onnx::Concat_183)
#   %onnx::Concat_197 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_3"](%onnx::Concat_194)
#   %onnx::Concat_196 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_4"](%onnx::Concat_183)
#   %onnx::Concat_195 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_5"](%onnx::Concat_183)
#   %onnx::Concat_193 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_6"](%onnx::Concat_183)
#   %onnx::Concat_192 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_7"](%onnx::Concat_183)
#   %onnx::Concat_190 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_8"](%onnx::Concat_183)
#   %onnx::Concat_189 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_9"](%onnx::Concat_183)
#   %onnx::Concat_188 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_10"](%onnx::Concat_185)
#   %onnx::Concat_187 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_11"](%onnx::Concat_183)
#   %onnx::Concat_186 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_12"](%onnx::Concat_183)
#   %onnx::Concat_184 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Identity[onnx_name="Identity_13"](%onnx::Concat_183)
#   %onnx::Gather_22 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_14"](%input_cpf) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_23 : Long(device=cpu) = onnx::Constant[value={1}, onnx_name="Constant_15"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_24 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_16"](%onnx::Gather_22, %onnx::Gather_23) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_25 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_17"](%input_cpf) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_26 : Long(device=cpu) = onnx::Constant[value={2}, onnx_name="Constant_18"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_27 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_19"](%onnx::Gather_25, %onnx::Gather_26) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Concat_31 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_20"](%onnx::Unsqueeze_27)
#   %onnx::Reshape_32 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_21"](%onnx::Concat_183, %onnx::Concat_31) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_33 : Float(*, *, strides=[60, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_22"](%input_cpf, %onnx::Reshape_32) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_34 : Float(60, 3540, strides=[3540, 1], requires_grad=0, device=cuda:0) = onnx::Constant[value=<Tensor>, onnx_name="Constant_23"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:184:0
#   %onnx::Reshape_35 : Float(*, 3540, strides=[3540, 1], requires_grad=0, device=cuda:0) = onnx::Gemm[alpha=1., beta=0., onnx_name="Gemm_24"](%onnx::Gemm_33, %onnx::Gemm_34) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_38 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_25"](%onnx::Unsqueeze_24)
#   %onnx::Reshape_40 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_26"](%onnx::Concat_184, %onnx::Concat_38, %onnx::Concat_185) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_41 : Float(*, *, *, strides=[106200, 3540, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_27"](%onnx::Reshape_35, %onnx::Reshape_40) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gather_42 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_28"](%input_cpf) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_43 : Long(device=cpu) = onnx::Constant[value={1}, onnx_name="Constant_29"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_44 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_30"](%onnx::Gather_42, %onnx::Gather_43) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_45 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_31"](%input_cpf) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_46 : Long(device=cpu) = onnx::Constant[value={2}, onnx_name="Constant_32"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_47 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_33"](%onnx::Gather_45, %onnx::Gather_46) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Concat_51 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_34"](%onnx::Unsqueeze_47)
#   %onnx::Reshape_52 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_35"](%onnx::Concat_186, %onnx::Concat_51) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_53 : Float(*, *, strides=[60, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_36"](%input_cpf, %onnx::Reshape_52) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_54 : Float(60, 3540, strides=[3540, 1], requires_grad=0, device=cuda:0) = onnx::Constant[value=<Tensor>, onnx_name="Constant_37"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:184:0
#   %onnx::Reshape_55 : Float(*, 3540, strides=[3540, 1], requires_grad=0, device=cuda:0) = onnx::Gemm[alpha=1., beta=0., onnx_name="Gemm_38"](%onnx::Gemm_53, %onnx::Gemm_54) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_58 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_39"](%onnx::Unsqueeze_44)
#   %onnx::Reshape_60 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_40"](%onnx::Concat_187, %onnx::Concat_58, %onnx::Concat_188) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_61 : Float(*, *, *, strides=[106200, 3540, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_41"](%onnx::Reshape_55, %onnx::Reshape_60) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Transpose_62 : Float(*, *, *, strides=[212400, 3540, 1], requires_grad=0, device=cuda:0) = onnx::Concat[axis=1, onnx_name="Concat_42"](%onnx::Concat_41, %onnx::Concat_61) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:100:0
#   %onnx::Reshape_63 : Float(*, *, *, strides=[212400, 60, 1], requires_grad=0, device=cuda:0) = onnx::Transpose[perm=[0, 2, 1], onnx_name="Transpose_43"](%onnx::Transpose_62) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:102:0
#   %onnx::Reshape_64 : Long(2, strides=[1], device=cpu) = onnx::Constant[value= -1  60 [ CPULongType{2} ], onnx_name="Constant_44"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:103:0
#   %onnx::Gemm_65 : Float(*, *, strides=[60, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_45"](%onnx::Reshape_63, %onnx::Reshape_64) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:103:0
#   %onnx::Relu_66 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_46"](%onnx::Gemm_65, %fr1.weight, %fr1.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Gemm_67 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_47"](%onnx::Relu_66) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Relu_68 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_48"](%onnx::Gemm_67, %fr2.weight, %fr2.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Gemm_69 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_49"](%onnx::Relu_68) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Reshape_70 : Float(*, 20, strides=[20, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_50"](%onnx::Gemm_69, %fr3.weight, %fr3.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Reshape_71 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=   -1  3540    20 [ CPULongType{3} ], onnx_name="Constant_51"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:105:0
#   %onnx::Relu_72 : Float(*, *, *, strides=[70800, 20, 1], requires_grad=1, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_52"](%onnx::Reshape_70, %onnx::Reshape_71) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:105:0
#   %onnx::Transpose_73 : Float(*, *, *, strides=[70800, 20, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_53"](%onnx::Relu_72) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Shape_74 : Float(*, *, *, strides=[70800, 3540, 1], requires_grad=1, device=cuda:0) = onnx::Transpose[perm=[0, 2, 1], onnx_name="Transpose_54"](%onnx::Transpose_73) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:107:0
#   %onnx::Gather_75 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_55"](%onnx::Shape_74) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_76 : Long(device=cpu) = onnx::Constant[value={1}, onnx_name="Constant_56"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_77 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_57"](%onnx::Gather_75, %onnx::Gather_76) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_78 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_58"](%onnx::Shape_74) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_79 : Long(device=cpu) = onnx::Constant[value={2}, onnx_name="Constant_59"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_80 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_60"](%onnx::Gather_78, %onnx::Gather_79) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Concat_84 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_61"](%onnx::Unsqueeze_80)
#   %onnx::Reshape_85 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_62"](%onnx::Concat_189, %onnx::Concat_84) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_86 : Float(*, *, strides=[3540, 1], requires_grad=1, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_63"](%onnx::Shape_74, %onnx::Reshape_85) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_87 : Float(3540, 60, strides=[60, 1], requires_grad=0, device=cuda:0) = onnx::Constant[value=<Tensor>, onnx_name="Constant_64"]()
#   %onnx::Reshape_88 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=0., onnx_name="Gemm_65"](%onnx::Gemm_86, %onnx::Gemm_87) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_91 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_66"](%onnx::Unsqueeze_77)
#   %onnx::Reshape_93 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_67"](%onnx::Concat_190, %onnx::Concat_91, %onnx::Concat_191) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_94 : Float(*, *, *, strides=[1200, 60, 1], requires_grad=1, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_68"](%onnx::Reshape_88, %onnx::Reshape_93) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gather_95 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_69"](%input_cpf) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_96 : Long(device=cpu) = onnx::Constant[value={1}, onnx_name="Constant_70"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_97 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_71"](%onnx::Gather_95, %onnx::Gather_96) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_98 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_72"](%input_cpf) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_99 : Long(device=cpu) = onnx::Constant[value={2}, onnx_name="Constant_73"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_100 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_74"](%onnx::Gather_98, %onnx::Gather_99) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Concat_104 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_75"](%onnx::Unsqueeze_100)
#   %onnx::Reshape_105 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_76"](%onnx::Concat_192, %onnx::Concat_104) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_106 : Float(*, *, strides=[60, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_77"](%input_cpf, %onnx::Reshape_105) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_107 : Float(60, 300, strides=[300, 1], requires_grad=0, device=cuda:0) = onnx::Constant[value=<Tensor>, onnx_name="Constant_78"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:184:0
#   %onnx::Reshape_108 : Float(*, 300, strides=[300, 1], requires_grad=0, device=cuda:0) = onnx::Gemm[alpha=1., beta=0., onnx_name="Gemm_79"](%onnx::Gemm_106, %onnx::Gemm_107) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_111 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_80"](%onnx::Unsqueeze_97)
#   %onnx::Reshape_113 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_81"](%onnx::Concat_193, %onnx::Concat_111, %onnx::Concat_194) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_114 : Float(*, *, *, strides=[9000, 300, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_82"](%onnx::Reshape_108, %onnx::Reshape_113) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gather_115 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_83"](%input_sv) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_116 : Long(device=cpu) = onnx::Constant[value={1}, onnx_name="Constant_84"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_117 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_85"](%onnx::Gather_115, %onnx::Gather_116) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_118 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_86"](%input_sv) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_119 : Long(device=cpu) = onnx::Constant[value={2}, onnx_name="Constant_87"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_120 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_88"](%onnx::Gather_118, %onnx::Gather_119) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Concat_124 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_89"](%onnx::Unsqueeze_120)
#   %onnx::Reshape_125 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_90"](%onnx::Concat_195, %onnx::Concat_124) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_126 : Float(*, *, strides=[5, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_91"](%input_sv, %onnx::Reshape_125) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_127 : Float(5, 300, strides=[300, 1], requires_grad=0, device=cuda:0) = onnx::Constant[value=<Tensor>, onnx_name="Constant_92"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:184:0
#   %onnx::Reshape_128 : Float(*, 300, strides=[300, 1], requires_grad=0, device=cuda:0) = onnx::Gemm[alpha=1., beta=0., onnx_name="Gemm_93"](%onnx::Gemm_126, %onnx::Gemm_127) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_131 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_94"](%onnx::Unsqueeze_117)
#   %onnx::Reshape_133 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_95"](%onnx::Concat_196, %onnx::Concat_131, %onnx::Concat_197) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_134 : Float(*, *, *, strides=[4200, 300, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_96"](%onnx::Reshape_128, %onnx::Reshape_133) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Transpose_135 : Float(*, *, *, strides=[13200, 300, 1], requires_grad=0, device=cuda:0) = onnx::Concat[axis=1, onnx_name="Concat_97"](%onnx::Concat_114, %onnx::Concat_134) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:114:0
#   %onnx::Reshape_136 : Float(*, *, *, strides=[13200, 44, 1], requires_grad=0, device=cuda:0) = onnx::Transpose[perm=[0, 2, 1], onnx_name="Transpose_98"](%onnx::Transpose_135) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:116:0
#   %onnx::Reshape_137 : Long(2, strides=[1], device=cpu) = onnx::Constant[value= -1  44 [ CPULongType{2} ], onnx_name="Constant_99"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:117:0
#   %onnx::Gemm_138 : Float(*, *, strides=[44, 1], requires_grad=0, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_100"](%onnx::Reshape_136, %onnx::Reshape_137) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:117:0
#   %onnx::Relu_139 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_101"](%onnx::Gemm_138, %fr1_pv.weight, %fr1_pv.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Gemm_140 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_102"](%onnx::Relu_139) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Relu_141 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_103"](%onnx::Gemm_140, %fr2_pv.weight, %fr2_pv.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Gemm_142 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_104"](%onnx::Relu_141) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Reshape_143 : Float(*, 20, strides=[20, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_105"](%onnx::Gemm_142, %fr3_pv.weight, %fr3_pv.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Reshape_144 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  -1  300   20 [ CPULongType{3} ], onnx_name="Constant_106"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:119:0
#   %onnx::Relu_145 : Float(*, *, *, strides=[6000, 20, 1], requires_grad=1, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_107"](%onnx::Reshape_143, %onnx::Reshape_144) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:119:0
#   %onnx::Transpose_146 : Float(*, *, *, strides=[6000, 20, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_108"](%onnx::Relu_145) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Shape_147 : Float(*, *, *, strides=[6000, 300, 1], requires_grad=1, device=cuda:0) = onnx::Transpose[perm=[0, 2, 1], onnx_name="Transpose_109"](%onnx::Transpose_146) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:121:0
#   %onnx::Gather_148 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_110"](%onnx::Shape_147) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_149 : Long(device=cpu) = onnx::Constant[value={1}, onnx_name="Constant_111"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_150 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_112"](%onnx::Gather_148, %onnx::Gather_149) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_151 : Long(3, strides=[1], device=cpu) = onnx::Shape[onnx_name="Shape_113"](%onnx::Shape_147) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Gather_152 : Long(device=cpu) = onnx::Constant[value={2}, onnx_name="Constant_114"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Unsqueeze_153 : Long(device=cpu) = onnx::Gather[axis=0, onnx_name="Gather_115"](%onnx::Gather_151, %onnx::Gather_152) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:183:0
#   %onnx::Concat_157 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_116"](%onnx::Unsqueeze_153)
#   %onnx::Reshape_158 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_117"](%onnx::Concat_198, %onnx::Concat_157) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_159 : Float(*, *, strides=[300, 1], requires_grad=1, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_118"](%onnx::Shape_147, %onnx::Reshape_158) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Gemm_160 : Float(300, 60, strides=[60, 1], requires_grad=0, device=cuda:0) = onnx::Constant[value=<Tensor>, onnx_name="Constant_119"]()
#   %onnx::Reshape_161 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=0., onnx_name="Gemm_120"](%onnx::Gemm_159, %onnx::Gemm_160) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_164 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0], onnx_name="Unsqueeze_121"](%onnx::Unsqueeze_150)
#   %onnx::Reshape_166 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0, onnx_name="Concat_122"](%onnx::Concat_199, %onnx::Concat_164, %onnx::Concat_200) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Concat_167 : Float(*, *, *, strides=[1200, 60, 1], requires_grad=1, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_123"](%onnx::Reshape_161, %onnx::Reshape_166) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:186:0
#   %onnx::Transpose_168 : Float(*, *, 60, strides=[4200, 60, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1, onnx_name="Concat_124"](%input_cpf, %onnx::Concat_94, %onnx::Concat_167) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:142:0
#   %onnx::Reshape_169 : Float(*, 60, *, strides=[4200, 70, 1], requires_grad=1, device=cuda:0) = onnx::Transpose[perm=[0, 2, 1], onnx_name="Transpose_125"](%onnx::Transpose_168) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:145:0
#   %onnx::Reshape_170 : Long(2, strides=[1], device=cpu) = onnx::Constant[value= -1  70 [ CPULongType{2} ], onnx_name="Constant_126"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:147:0
#   %onnx::Gemm_171 : Float(*, *, strides=[70, 1], requires_grad=1, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_127"](%onnx::Reshape_169, %onnx::Reshape_170) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:147:0
#   %onnx::Relu_172 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_128"](%onnx::Gemm_171, %fo1.weight, %fo1.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Gemm_173 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_129"](%onnx::Relu_172) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Relu_174 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_130"](%onnx::Gemm_173, %fo2.weight, %fo2.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Gemm_175 : Float(*, 60, strides=[60, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_131"](%onnx::Relu_174) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Reshape_176 : Float(*, 24, strides=[24, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_132"](%onnx::Gemm_175, %fo3.weight, %fo3.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %onnx::Reshape_177 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= -1  60  24 [ CPULongType{3} ], onnx_name="Constant_133"]() # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:149:0
#   %onnx::Relu_178 : Float(*, *, *, strides=[1440, 24, 1], requires_grad=1, device=cuda:0) = onnx::Reshape[onnx_name="Reshape_134"](%onnx::Reshape_176, %onnx::Reshape_177) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:149:0
#   %onnx::ReduceSum_179 : Float(*, *, *, strides=[1440, 24, 1], requires_grad=1, device=cuda:0) = onnx::Relu[onnx_name="Relu_135"](%onnx::Relu_178) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1457:0
#   %onnx::Gemm_180 : Float(*, *, strides=[24, 1], requires_grad=1, device=cuda:0) = onnx::ReduceSum[axes=[1], keepdims=0, onnx_name="ReduceSum_136"](%onnx::ReduceSum_179) # /home/ruike/hbb_interaction_network/notebooks/../src/models/models.py:165:0
#   %input : Float(*, 2, strides=[2, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="Gemm_137"](%onnx::Gemm_180, %fc_fixed.weight, %fc_fixed.bias) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114:0
#   %output1 : Float(*, 2, strides=[2, 1], requires_grad=1, device=cuda:0) = onnx::Softmax[axis=1, onnx_name="Softmax_138"](%input) # /lus/theta-fs0/software/thetagpu/conda/2022-07-01/mconda3/lib/python3.8/site-packages/torch/nn/functional.py:1834:0
#   return (%output1)

# %%
import tqdm
from scipy.special import softmax
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score

pbar = tqdm.tqdm(range(int(sample_size/batch_size)-1))
for i in pbar:   
    start_idx = i*batch_size
    label_batch = label_all[1+start_idx:1+start_idx+batch_size]
    
    
    dummy_input_1 = torch.from_numpy(test[1+start_idx:1+start_idx+batch_size]).cuda()
    dummy_input_2 = torch.from_numpy(test_sv[1+start_idx:1+start_idx+batch_size]).cuda() 
    
    #use pytorch gnn to predict
    start_time = time.perf_counter() 
    out_test = gnn(dummy_input_1, dummy_input_2)
    end_time = time.perf_counter() 
    temp_=end_time-start_time
    
    pytorch_time.append(temp_)
    
       
    # Load the ONNX model
    dummy_input_1 = test[1+start_idx:1+start_idx+batch_size]
    dummy_input_2 = test_sv[1+start_idx:1+start_idx+batch_size]
    model = onnx.load(model_path)

    # Check that the IR is well formed
    onnx.checker.check_model(model)

    # Print a human readable representation of the graph
    ####print(onnx.helper.printable_graph(model.graph))

    
    options = ort.SessionOptions()
    options.intra_op_num_threads = 1
    ort_session = ort.InferenceSession(model_path, options, providers=[('CUDAExecutionProvider')])

    # compute ONNX Runtime output prediction
    start_time = time.perf_counter()
    ort_inputs = {ort_session.get_inputs()[0].name: dummy_input_1,
              ort_session.get_inputs()[1].name: dummy_input_2}

     
    ort_outs = ort_session.run(None, ort_inputs)
    end_time = time.perf_counter() 
    #print(f"ONNXRuntime Inference in {toc - tic:0.4f} seconds")
    time_ = end_time-start_time
    onnx_time.append(time_)


    temp_onnx_res = ort_outs[0].tolist()
    temp_pytorch_res = out_test.cpu().detach().numpy().tolist()
    
    for x in label_batch:
        label_.append(x.tolist())
        
    for x in temp_onnx_res:
        onnx_res.append(x)
        x_ = softmax(x, axis=0)
        onnx_soft_res.append(x_.tolist())
    for x in temp_pytorch_res:
        torch_res.append(x)
        x_ = softmax(x, axis=0)
        torch_soft_res.append(x_.tolist())
# Out:
#   9%|▉         | 1310/14061 [07:50<1:17:33,  2.74it/s]

# %%
clip_onnx_soft_res = []
clip_torch_soft_res=[]
clip_label = []
for i in range(len(label_)):
    if [0.,0,] == label_[i]:
        continue
    else:
        clip_onnx_soft_res.append(onnx_soft_res[i])
        clip_torch_soft_res.append(torch_soft_res[i])
        clip_label.append(label_[i])
        
# print(len(torch_res))

fpr_o, tpr_o, thresholds_p = _m.roc_curve(np.array(clip_label)[:,1], np.array(clip_onnx_soft_res)[:,1])
print("onnx acc",accuracy_score(np.array(clip_label)[:,1], np.array(clip_onnx_soft_res)[:,1]>0.5))
print("onnx auc",_m.auc(fpr_o, tpr_o) ) 
print("onnx",np.mean(onnx_time[1:]))

print("#############################")
fpr_p, tpr_p, thresholds_p = _m.roc_curve(np.array(clip_label)[:,1], np.array(clip_torch_soft_res)[:,1])
print("torch acc",accuracy_score(np.array(clip_label)[:,1], np.array(clip_torch_soft_res)[:,1]>0.5))
print("torch auc",_m.auc(fpr_p, tpr_p) ) 
print("pytorch",np.mean(pytorch_time[1:]))
# Out:
# 0.0012258581570294329
# 0.012636007546190493

# %%
# singularity shell --bind //grand/RAPINS/ruike/new_hbb/test://home/ruike/merge_IN/notebook_code/test_hbb //home/ruike/trt_torch_new.sif ls //home/ruike/merge_IN/notebook_code/test_hbb
