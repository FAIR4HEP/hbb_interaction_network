[25181.48588494301, 26240.68593344238, 25846.480777833538, 26051.064438775975, 26129.04576613459, 25780.737755661685, 26039.494685000624, 25341.563206879484, 25273.189195044124, 27127.872368979646],
[22645.534112359685, 23993.85015186094, 23842.402085305992, 23588.394160088643, 23485.70247543539, 23608.09539313433, 23580.710239413682, 23972.279683518616, 23620.45134812383, 23769.723206297014],
[22544.915489070027, 23616.76546992268, 23259.83697529573, 24343.276709888778, 24103.02337761391, 24293.888701284104, 24170.81540930927, 24248.918985062217, 24165.48054297164, 23741.654738996],
[22535.297384119734, 23348.677398768054, 23423.714830616573, 22924.451568826684, 23359.575974979, 22941.697982293226, 23532.09325496991, 23777.14585409908, 23481.569312518528, 24371.762779501085],
[22633.85490828251, 23397.475017334382, 23315.75378680641, 23000.086149930994, 23286.398885341165, 23593.237600688775, 23462.241114046832, 23638.21315566713, 23328.899741110403, 23144.30278655512]  
]

print(len(x1))
print(len(y1))
plt.figure(figsize=(10, 6))

# plt.title("throughtput with batchsize")
# plt.plot(x1, y1, label='throughput', linewidth=1, color='r', marker='o',
#          markerfacecolor='red', markersize=3)

plt.boxplot(y1, labels=x1, patch_artist = True,boxprops = {'color':'orangered','facecolor':'pink'})
 
plt.xlabel('batch size',fontsize=12)
plt.ylabel('throughput',fontsize=12)
 

# for a, b in zip(x1, y1):
#     plt.text(a, b, b, ha='center', va='bottom', fontsize=9)
 
plt.legend()
plt.savefig('./pics/throughput.png')

# print("max throughput:", np.max(y1), "when batchsize is:", x1[np.argmax(y1)])
# Out:
# No handles with labels found to put in legend.
# 18
# 18

# %% [markdown]
# below is the curve of GPU utility and batchsize. The gpu utility is get by 'nvidia-smi'

# %%
x1 = [200,400,600,800,1000,1200,1400,1500,1600,1800,2000,2200,2400,2600,3000,3400,3800,4200]

y1 = [51,71,93,95,100,100,100,100,100,100,100,100,100,100,100,100,100,100]
print(len(x1))
print(len(y1))
plt.figure(figsize=(8, 6))


# plt.title("GPU utility with batchsize")
plt.plot(x1, y1, linewidth=1, color='r', marker='o',
         markerfacecolor='red', markersize=3)
 
plt.xlabel('batch size',fontsize=12)
plt.ylabel('GPU utilization',fontsize=12)
 

# for a, b in zip(x1, y1):
#     plt.text(a, b, b, ha='center', va='bottom', fontsize=9)
 
plt.legend()
plt.savefig('./pics/gpu.png')

print("max gpu utility:", np.max(y1), "when batchsize is:", x1[np.argmax(y1)])
# Out:
# No handles with labels found to put in legend.
# 18
# 18
# max gpu utility: 100 when batchsize is: 1000
